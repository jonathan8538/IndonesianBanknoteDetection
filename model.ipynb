# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
results = model.train(
    data='D:\project\IndonesianBankNotesRecognition\Indonesian Banknotes.v1i.yolov8-obb\data.yaml',
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# ...
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2544\1120139383.py:3: SyntaxWarning: invalid escape sequence '\p'
#   data='D:\project\IndonesianBankNotesRecognition\Indonesian Banknotes.v1i.yolov8-obb\data.yaml',
# 100%|██████████| 6.25M/6.25M [00:02<00:00, 3.16MB/s]
# New https://pypi.org/project/ultralytics/8.3.108 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.107  Python-3.12.3 torch-2.6.0+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# ...

# %%
model = YOLO(r'D:\project\IndonesianBankNotesRecognition\runs\detect\train12\weights\best.pt')
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.107  Python-3.12.3 torch-2.6.0+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# Model summary (fused): 72 layers, 3,007,013 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\project\IndonesianBankNotesRecognition\Indonesian Banknotes.v1i.yolov8-obb\valid\labels.cache... 67 images, 0 backgrounds, 0 corrupt: 100%|██████████| 67/67 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:07<00:00,  1.45s/it]
#                    all         67         67      0.985      0.998      0.987      0.882
#                   1000         67         67      0.985      0.998      0.987      0.882
# Speed: 2.6ms preprocess, 92.6ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs\detect\val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
import pandas as pd
from ultralytics import YOLO

model = YOLO(r'D:\project\IndonesianBankNotesRecognition\runs\detect\train12\weights\best.pt')

metrics = model.val()
results_dict = metrics.results_dict
df_metrics = pd.DataFrame(list(results_dict.items()), columns=['Metric', 'Value'])
print(df_metrics)
# Out:
# Ultralytics 8.3.107  Python-3.12.3 torch-2.6.0+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# Model summary (fused): 72 layers, 3,007,013 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\project\IndonesianBankNotesRecognition\Indonesian Banknotes.v1i.yolov8-obb\valid\labels.cache... 67 images, 0 backgrounds, 0 corrupt: 100%|██████████| 67/67 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:09<00:00,  1.92s/it]
#                    all         67         67      0.985      0.998      0.987      0.882
#                   1000         67         67      0.985      0.998      0.987      0.882
# Speed: 5.2ms preprocess, 108.0ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs\detect\val2
#                  Metric     Value
# 0  metrics/precision(B)  0.985262
# 1     metrics/recall(B)  0.997821
# 2      metrics/mAP50(B)  0.986765
# 3   metrics/mAP50-95(B)  0.881651
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

img = Image.open(r'D:\project\IndonesianBankNotesRecognition\runs\detect\train12\results.png')
plt.figure(figsize=(15,8))
plt.imshow(img)
plt.axis('off')
plt.show()
